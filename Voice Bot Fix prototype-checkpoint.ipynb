# %%
#Import library
from newspaper import Article
import random
import nltk
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import random

import datetime
import gtts
from playsound import playsound
import speech_recognition as sr

# %%
article = Article('https://www.brilio.net/wow/40-kata-kata-sedih-kehidupan-menyentuh-hati-dan-bikin-nangis-1910033.html')
article.download()
article.parse()
article.nlp()
corpus = article.text
print(corpus)
# Out:
# Brilio.net - Roda kehidupan selalu berputar. Ada kalanya orang berada di atas, kadang juga ada di bawah. Peristiwa hidup silih berganti, ada rasa bahagia, kecewa, senang, sedih, marah. Semua itu pernah dirasakan setiap orang. Dalam menjalani kehidupan, terkadang mengalami kesedihan yang mendalam.
#
# Rasa sedih itu bisa terjadi karena berbagai faktor. Bisa karena cinta, pekerjaan, keluarga, pertemanan, tetangga, ataupun dari diri sendiri. Saat sedang sedih, biasanya badan akan terasa malas untuk beraktivitas dan hanya bisa melontarkan kekesalan dan kekecewaan di dalam hati. Tak sedikit juga yang mau berbagi kesedihan melalui media sosial.
#
# Manusia adalah makhluk Tuhan, dikaruniai perasaan dan juga akal. Itulah yang menjadi salah satu alasan kata-kata sedih terasa mampu menanggapi, menggambarkan dan mewakili perasaan. Meskipun begitu sebagai manusia jangan lah terlalu berlarut-larut dalam kesedihan. Serahkan diri pada Yang Maha Kuasa dan kembalilah untuk bangkit.
#
# Nah, berikut beberapa kata-kata sedih yang mungkin bisa mewakili perasaanmu. Jadikan pengalaman sedihmu sebagai pelajaran berharga, agar kamu bisa lebih kuat lagi. Simak rangkuman brilio.net dari berbagai sumber pada Selasa (29/6).
#
# ANDA MUNGKIN MENYUKAI INI
#
# Kata-kata sedih tentang kehidupan.
#
# foto: Instagram/@motivasi_kaya
#
# Hidup tidak selamanya berjalan dengan mulus. Sedih dan kecewa kerap datang. Setidaknya perasaanmu sedikit terwakilkan dengan membaca kata-kata sedih berikut ini.
#
# 1. "Sakit sekali rasanya ketika kamu sudah melakukan yang terbaik, tapi ternyata masih tidak cukup."
#
# 2. "Jangan khawatir akan hari esok kesusahan hari ini cukuplah hari ini."
#
# 3. "Ketika kamu merasa sangat terluka atas sikap orang lain, maka berdoalah kepada Allah agar kamu tidak berbuat seperti apa yang telah dilakukannya."
#
# 4. "Aku tidak tahu apakah tempatku benar-benar di sini. Aku tidak punya seorangpun untuk diajak bicara."
#
# 5. "Setiap kali orang bertanya padaku apakah aku baik-baik saja, hal ini semakin mengingatkan bahwa aku tidak baik-baik saja."
#
# 6. "Orang menangis bukan karena mereka lemah. Tapi, mereka menangis karena telah berusaha kuat dalam waktu yang lama." - Johnny Depp
#
# 7. "Proses pendewasaan dalam hidup ini adalah melalui ujian-ujian yang terjadi dalam hidupmu."
#
# 8. "Bagiku, tidur bukanlah sekadar melepas lelah, melainkan sebuah pelarian."
#
# 9. "Bukan hal yang mudah melepaskan atau mempertahankan apa yang semula baik tiba-tiba berubah drastis menjadi amat buruk."
#
# 10. "Salah satu perlindungan dari kekecewaan adalah memiliki kesibukan." - Alain de Botton.
#
# 11. "Aku berharap aku dapat memberikan rasa sakitku hanya untuk sesaat sehingga kamu dapat memahami betapa kamu menyakitiku." - Mohsen El- guindy.
#
# 12. "Beberapa hari hanyalah hari yang buruk, itu saja. Kamu harus mengalami kesedihan untuk mengetahui kebahagiaan, dan saya mengingatkan diri saya sendiri bahwa tidak setiap hari akan menjadi hari yang baik, begitulah adanya!" - Dita Von Teese.
#
# 13. "Air mata yang menetes untuk orang lain bukanlah pertanda kelemahan. Itu adalah tanda hati yang murni." - José N. Harris.
#
# 14. "Banyak hal berubah. Dan teman-teman pergi. Hidup tidak berhenti untuk siapa pun." - Stephen Chbosky.
#
# 15. "Rasa sakit berkeras saat dirawat. Tuhan berbisik kepada kita dalam kesenangan kita, berbicara dalam hati nurani kita, tetapi berteriak dalam kesakitan kita. Itu megafon-Nya untuk membangkitkan dunia yang tuli." - CS Lewis.
#
# 16. "Sungguh menyakitkan melihat orang yang sangat kamu cintai, mencintai orang lain. Tapi, itu lebih menyakitkan ketika kamu mengetahui bahwa kamu hanyalah jembatan mereka untuk menyeberang ke orang yang mereka cintai."
#
# 17. "Menyedihkan mengetahui bahwa saya sudah selesai. Tapi, melihat ke belakang, saya punya banyak kenangan indah." - Bonnie Blair.
#
# 18. "Kamu bertemu semua orang dua kali dalam hidup ini, saat mereka datang dan saat mereka pergi." - CC Aurel.
#
# 19. "Selama ini cinta tidak mengenal kedalamannya sendiri sampai saat perpisahan." - Kahlil Gibran.
#
# 20. "Tidak ada yang lebih buruk daripada ketika seseorang yang seharusnya mencintaimu, pergi begitu saja." - Ava Dellaira.
#
# 21. "Kamu tidak pernah bisa mengontrol dengan siapa kamu jatuh cinta, bahkan ketika kamu berada di saat yang paling menyedihkan dan membingungkan dalam hidupmu. Kamu tidak jatuh cinta dengan orang lain karena mereka menyenangkan. Itu terjadi begitu saja." - Kirsten Dunst.
#
# 22. "Biarlah jiwaku tersenyum melalui hatiku dan hatiku tersenyum melalui mataku agar aku dapat menyebarkan senyuman yang kaya di dalam hati yang sedih." - Paramahansa Yogananda.
#
# 23. "Biarkan aku menyimpan bagian terakhir hatiku sebelum kau merobek semuanya." - Lykke Li.
#
# 24. "Dinding yang kita bangun di sekitar kita untuk menahan kesedihan, juga menahan kegembiraan." - Jim Rohn.
#
# 25. "Hal yang paling menyakitkan adalah kehilangan diri sendiri dalam proses terlalu mencintai seseorang, dan lupa bahwa kamu juga spesial." - Ernest Hemingway.
#
# 26. "Pertama, terimalah kesedihan. Sadarilah bahwa tanpa kalah, menang tidaklah terlalu bagus." - Alyssa Milano.
#
# 27. "Jangan pernah membandingkan dirimu dengan orang lain karena mereka tidak tahu saat burukmu dan kamu tidak tahu tentang mereka."
#
# 28. "Kata 'bahagia' akan kehilangan artinya jika tidak diimbangi dengan kesedihan." - Carl Jung.
#
# 29. "Kamu tidak dapat melindungi diri dari kesedihan tanpa melindungi diri dari kebahagiaan." - Jonathan Safran Foer.
#
# 30. "Air mata keluar dari hati dan bukan dari otak." - Leonardo da Vinci.
#
# 31. "Kamu tidak bisa membeli cinta, tapi kamu bisa membayar mahal untuk itu." - Henny Youngman.
#
# 32. "Menangis sendiri tidak menunjukkan bahwa kamu lemah, tetapi itu menunjukkan bahwa kamu kuat."
#
# 33. "Pernikahan bukanlah hiburan, melainkan tindakan yang serius, dan umumnya menyedihkan." - Ratu Victoria.
#
# 34. "Hal-hal yang menyedihkan terjadi. Tapi, kita tidak perlu hidup sedih selamanya." - Mattie Stepanek.
#
# 35. "Jika kamu adalah orang yang berhati baik, kamu mengalami lebih banyak masalah daripada yang lain."
#
# 36. "Ada waktu untuk berangkat, meski tidak ada tempat pasti untuk pergi." - Tennessee Williams.
#
# 37. "Saat kamu merasakan sakit, ingatlah itu pertanda bahwa dosa-dosamu makin berkurang."
#
# 38. "Dia mengajariku bagaimana mencintai, tapi bukan bagaimana berhenti."
#
# 39. "Orang akan melihat kesuksesanmu, tetapi mereka tidak akan melihat perjuanganmu."
#
# 40. "Hidup itu sulit, kamu harus kuat dari dalam."
#
# 41. "Aku pernah berharap untuk menghilang saja dari dunia ini. Dunia ini terlihat begitu gelap dan aku menangis sepanjang malam. Apakah aku akan merasa lebih baik jika aku menghilang?"
#
# 42. "Ketika satu pintu menutup, pintu lain terbuka; tetapi kita begitu sering melihat begitu lama dan sangat menyesal pada pintu yang tertutup sehingga kita tidak melihat pintu yang terbuka untuk kita." - Alexander Graham Bell.
#
# 43. "Jangan menangis karena sudah berakhir, tersenyumlah karena sudah terjadi." - Dr. Seuss.
#
# 44. "Kesedihan hanyalah sebuah tembok di antara dua taman." - Khalil Gibran.
#
# 45. "Saat-saat indah hari ini adalah saat-saat sedih di masa depan." - Bob Marley.
#
# 46. "Setiap orang memiliki rahasia dukacita yang tidak diketahui dunia; dan sering kali kita menyebut orang yang dingin, padahal dia hanya sedih." - Henry Wadsworth Longfellow
#
# 47. "Air mata adalah kata-kata yang perlu dituliskan." - Paulo Coelho.
#
# 48. "Kesedihan juga merupakan salah satu bentuk pembelaan." - Ivo Andric.
#
# 49. "Kamu sangat peduli sehingga kamu merasa seolah-olah kamu akan mati kehabisan darah dengan rasa sakit itu." - JK Rowling.
#
# 50. "Daripada menangis dan mendambakan mereka yang meninggalkan jalan kita selama saat-saat gelap dalam hidup kita, mari luangkan waktu untuk berterima kasih kepada mereka yang berdiri dan membantu kita melewati jalan gelap itu." - Nehali Lalwani.
#
# Kata-kata sedih untuk pacar.
#
# foto: Instagram/@hujansore.id
#
# Rasa sakit itu mengajarimu agar bisa lebih dewasa, lebih hati-hati dan jadi lebih baik lagi. Menangislah jika ingin menangis, bukan karena lemah, tapi menangis karena sudah berusaha kuat sekian lama.
#
# Ketika kamu sedang menghadapi kesedihan karena sang kekasih, kamu bisa mengungkapkannya lewat kata-kata berikut ini.
#
# 51. "Kata-kata lebih menyakitkan daripada apapun, karena mereka bertahan, kadang selamanya."
#
# 52. "Mungkin kebahagiaan bersamamu hanya seperti mimpi, tapi biarlah mimpi itu terus menemani di setiap tidurku."
#
# 53. "Suatu saat kamu akan merasakan apa yang sedang aku rasakan saat ini. Sakit hatiku tak akan sembuh jika masih bersamamu."
#
# 54. "Aku tak mampu melupakanmu tapi aku sanggup melepaskanmu."
#
# 55. "Rasanya sakit untuk melepaskan, tetapi kadang-kadang lebih menyakitkan untuk bertahan."
#
# 56. "Sungguh luar biasa mengetahui ada seseorang yang bisa menghancurkan hatimu dan kau tetap mencintainya dengan serpihan-serpihan itu."
#
# 57. "Akan lebih mudah untuk memaafkan orang biasa daripada memaafkan luka yang diberi oleh orang tercinta."
#
# 58. "Alangkah baiknya aku pergi dari hidupmu, karena aku bukan siapa-siapa lagi di hatimu. Aku setia kamu mendua, aku mencintai kamu malah pergi."
#
# 59. "Meskipun ku tak siap untuk merindu, ku tak siap tanpa dirimu, kuharap terbaik untukmu." – Endank Soekamti.
#
# 60. "Jika aku memperlakukanmu sama seperti kau memperlakukanku. Kau pasti membenciku."
#
# 61. "Jatuh hati mengajarkan aku bagaimana memberanikan diri. Juga bagaimana menjadi sabar saat kau tinggalkan sendiri."
#
# 62. "Seseorang seringkali kecewa dengan cinta yang ia harapkan dan tidak dengan cinta yang telah diberikan."
#
# 63. "Aku menikmati setiap detik bersamamu, jika kelak kau pergi aku telah memiliki semua itu dalam ingatanku."
#
# 64. "Kita saling menghancurkan dengan kebersamaan. Kita menghancurkan mimpi satu sama lain."
#
# 65. "Ketika kesabaran yang aku miliki mulai pudar, jangan tanya kenapa. Cukup kamu lihat saja dan mengerti kenapa aku begini."
#
# 66. "Hampa itu seperti langkah tak berjejak, senja tapi tak jingga, cinta tapi tak dianggap."
#
# 67. "Aku memang sering kali bersabar, namun alangkah baiknya jika kamu tidak menguji kesabaranku."
#
# 68. "Pundakku mungkin takkan selalu ada saat kamu bersedih dan menangis, tapi cintaku akan selalu ada untukmu."
#
# 69. "Tenanglah, aku yakin jarak akan mengalah, sebab ia bosan mendengar rindu."
#
# 70. "Mungkin hanya aku yang merindukanmu, meneteskan air mata, dan berharap bertemu secepatnya."
#
# 71. "Ketika kepercayaan dirusak, kata maaf sudah tak ada artinya lagi."
#
# 72. "Kamu akan benar-benar kecewa jika kamu berpikir orang akan memperlakukanmu seperti kamu memperlakukan mereka. Tidak semua orang memiliki hati yang sama sepertimu."
#
# 73. "Setidaknya, ketika kita terpisah jarak, ingatlah bahwa ada sosok yang menunggumu untuk lekas pulang."
#
# 74. "Harapan adalah akar dari semua sakit hati."
#
# 75. "Tidak akan ada kekecewaan yang mendalam di mana tidak ada cinta yang mendalam."
#
# 76. "Lebih menyakitkan diabaikan daripada dibenci, karena itu membuatmu merasa seperti tidak berarti."
#
# 77. "Seperti adanya, kita menderita karena kita membayangkan berbeda."
#
# 78. "Jika kau tidak bahagia denganku, maka setidaknya bahagialah tanpa diriku."
#
# 79. "Saat kita jauh, jangan pernah sekalipun membenci jarak, karena sejatinya jarak membuat rindu itu terjadi."
#
# 80. "Kamu yang membuat aku mengerti arti dari kecewa dan patah hati."
#
# Kata-kata kesedihan dalam bahasa Inggris.
#
# foto: freepik.com
#
# Semua kesedihan itu begitu terasa sakit jika kamu memendamnya sendiri. Carilah teman bicara dan berusahalah untuk mengikhlaskan semuanya. Jadikan kesedihan dalam hidupmu sebagai pembelajaran. Lalu luangkan waktu dan segeralah bangkit dari kesedihan.
#
# Jika tak bisa menceritakannya pada orang-orang, kamu bisa meluapkannya dengan air mata atau sekadar dengan kata-kata. Untuk mewakili perasaanmu, berikut beberapa kata-kata sedih bahasa Inggris.
#
# 81. "Just because I am strong enough to handle pain doesn't mean I deserve it."
#
# (Hanya karena aku cukup kuat untuk menangani rasa sakit, bukan berarti aku pantas mendapatkannya)
#
# 82. "Nobody is very tough in this life. Everybody feels the sadness but they sometimes pretend to smile."
#
# (Tidak ada orang yang benar-benar sangat kuat dalam hidup ini. Setiap orang merasakan kesedihan tetapi mereka terkadang berpura-pura tersenyum)
#
# 83. "This life is a choice. Whatever makes you sad, leave it. And, whatever makes you smile, hold it."
#
# (Hidup ini adalah pilihan. Apa saja yang membuatmu sedih maka tinggalkanlah, apa saja yang membuatmu tersenyum, genggamlah)
#
# 84. "So much more was said in the unsaid."
#
# (Lebih banyak lagi yang dikatakan dalam kata yang tak terucapkan)
#
# 85. "For you, I was a chapter. For me, you were the book."
#
# (Untukmu, aku hanyalah sebuah bab dari buku. Dan untukku, kamu adalah sebuah buku)
#
# 86. "Tears dry, but the pain drowns."
#
# (Air mata mengering, tetapi rasa sakitnya tenggelam semakin dalam)
#
# 87. "Someone who looks tough is not the one who never feels sad. He behave like nothing is wrong, but his heart is hurt."
#
# (Seseorang yang terlihat kuat bukanlah seseorang yang tidak pernah merasakan sedih. Ia bersikap seperti tidak ada yang salah walaupun hatinya terasa sakit/terluka)
#
# 88. "When someone hurts you, do not be sad. God has the cure."
#
# (Ketika seseorang melukaimu, jangan bersedih. Tuhan memiliki penyembuhnya)
#
# 89. "He taught me how to love, but not how to stop."
#
# (Dia mengajarkanku cara untuk mencintai, tapi tidak cara untuk berhenti)
#
# 90. "People cry, not because they're weak. It's because they've been strong for too long."
#
# (Orang-orang menangis, bukan karena mereka lemah. Ini disebabkan karena mereka menjadi kuat untuk waktu yang terlalu lama)
#
# 91. "Stab the body and it heals, but injure the heart and the wound lasts a lifetime." - Mineko Iwasaki.
#
# (Tusuklah tubuh seseorang dan itu bisa disembuhkan, tetapi sakiti hatinya maka lukanya akan berbekas seumur hidup)
#
# 92. "You can choose to feel sad of what you lose in your life or happy of what you have."
#
# (Kamu bisa memilih untuk bersedih atas apa yang hilang dalam hidupmu atau bahagia atas apa yang kamu miliki)
#
# 93. "I'm not mad. I'm hurt. There's a difference."
#
# (Aku tidak marah. Aku terluka. Disana terdapat perbedaan)
#
# 94. "I think I have known you well, but now I know I am wrong."
#
# (Aku pikir aku sudah mengenalmu dengan baik, tetapi sekarang aku tahu aku salah)
#
# 95. "Moving on is simple, it's what you leave behind that makes it so difficult."
#
# (Melanjutkan hidup kembali itu mudah, yang sulit adalah meninggalkan masa lalu)
#
# 96. "All the memories come back, but he never does."
#
# (Semua kenangan akan kembali, tetapi ia tidak pernah sama sekali)
#
# 97. "Tears are words the heart can't express."
#
# (Air mata adalah kata-kata yang tidak bisa diungkapkan oleh hati)
#
# 98. "Hardest thing in the world is fixing a heart you didn't break by yourself."
#
# (Hal tersulit di dunia adalah memperbaiki hati yang tidak engkau hancurkan sendiri)
#
# 99. "Love can sometimes be magic but magic can sometimes just be an illusion."
#
# (Terkadang cinta adalah sebuah keajaiban, tetapi terkadang juga hanya sebuah ilusi)
#
# 100. "If the threes abort the leaves to stay alive. So I want to loss you to make you and I still happy."
#
# (Jika pohon-pohon menggugurkan dedaunannya untuk bertahan hidup, aku pun ingin kehilangan kamu untuk membuat kamu dan aku tetap bahagia)
#
# 101. "Better to be praised secretly by just one person who is the best in giving always openly an honest opinion than to be liked openly by any number of people who are good for nothing but just often make fun secretly of others." - Anuj Somany.
#
# (Lebih baik dipuji sembunyi-sembunyi oleh satu orang yang terbaik dalam memberi opini jujur yang terbuka, daripada oleh banyak orang yang tidak baik untuk apa-apa, sebaliknya hanya sering mengejek orang lain secara sembunyi-sembunyi)
#
# 102. "The word "friend" is a label anyone can try on. You decide who is best suited to wear it." - Carlos Wallace.
#
# (Kata "teman" merupakan label yang siapapun dapat coba. Kamu memutuskan siapa yang paling pantas untuk mengenakannya)
#
# 103. "It hurts the most when you can actually feel your heart breaking."
#
# (Yang paling menyakitkan adalah saat kamu benar merasakan bahwa kamu sedang patah hati)
#
# 104. "I have a thousand reasons to stick with you. However, you have a thousand reasons to leave me."
#
# (Aku memiliki seribu alasan untuk bertahan denganmu. Namun, kamu memiliki seribu satu alasan untuk meninggalkanku)
#
# 105. "When my heart is broken, my boats are burned: nothing matters anymore. It is the end of happiness, but the beginning of peace."
#
# (Ketika hatiku hancur, perahuku terbakar: tidak ada yang penting lagi. Itu memang akhir dari kebahagiaan, tapi awal dari kedamaian)
#
# 106. "No one realizes the beauty of love, until you lose it."
#
# (Tidak ada yang sadar mengenai keajaiban cinta, hingga kamu kehilangan cinta)
#
# 107. "Pleasure of love lasts but a moment. Pain of love lasts a lifetime." - Bette Davis.
#
# (Kebahagiaan karena cinta hanya berlangsung sekejap saja, namun kekecewaan karena cinta berlangsung selamanya)
#
# 108. "It is somehow painful when you can lay your life down for them, but they won't be there for you, even when you need them the most." - Goals Rider.
#
# (Hal ini entah bagaimana menyakitkan ketika kamu bisa mencurahkan hidupmu untuk mereka, namun mereka tidak akan disana untukmu, bahkan saat kamu sangat membutuhkan mereka)
#
# 109. "Broken heart is funny to everyone, except those who are heartbroken. For me, heartbreak is very very not funny."
#
# (Hati yang hancur itu lucu bagi semua orang, kecuali yang patah hati. Bagiku patah hati sangat sangat tidak lucu)
#
# 110. "Love don't cost a thing: except a lot of tears, a broken heart, and wasted years."
#
# (Cinta tidak meminta bayaran apapun: kecuali setumpuk air mata, hati yang hancur dan membuang waktu)
#
# 111. "I used to think enemies were the worst people in the world, but that was until I met fake friends and realized that they're a lot worse."
#
# (Saya dulu berpikir bahwa musuh adalah orang terburuk di dunia, namun itu hanya sampai saya bertemu teman palsu dan menyadari bahwa mereka jauh lebih buruk)
#
# 112. "Forgiving your enemy is easier than try to forgive your best friend."
#
# (Memaafkan musuhmu lebih mudah daripada mencoba memaafkan sahabatmu)
#
# 113. "When someone breaks your trust don't feel stupid for trusting them. You didn’t do anything wrong. They're just an untrustworthy person." - Sonya Parker.
#
# (Ketika seseorang menghancurkan kepercayaannya jangan merasa bodoh karena mempercayainya. Kamu tidak melakukan kesalahan apapun. Mereka hanya orang yang tidak dapat dipercaya)
#
# 114. "It takes a strong heart to love, but it takes an ever stronger heart to continue to love after it's been hurt."
#
# (Dibutuhkan hati yang kuat untuk mencintai, tetapi dibutuhkan hati yang lebih kuat untuk terus mencintai setelah terluka)
#
# 115. "When one has lost a friend one's eyes should be neither dry nor streaming. Tears, yes, there should be, but not lamentation." - Seneca
#
# (Ketika seseorang telah kehilangan seorang teman, matanya seharusnya tidak kering atau mengalir. Air mata, iya, harus ada, tapi tidak ratapan)
#
# 116. "I hate you for not letting me have you."
#
# (Aku membencimu karena kau tak membiarkanku memilikimu)
#
# 117. "Pain is inevitable, suffering is optional."
#
# (Rasa sakit tidak bisa dihindari tetapi penderitaan adalah pilihan)
#
# 118. "A broken heart is the worst. It's like having broken ribs. Nobody can see it but the pain is unbearable every time I breathe."
#
# (Hati yang hancur adalah yang terburuk. Ini seperti memiliki tulang rusuk yang patah. Tidak ada yang bisa melihatnya tetapi rasa sakitnya tak tertahankan setiap kali aku bernapas)
#
# 119. "Love is blind, but a broken heart sees everything."
#
# (Cinta itu buta, tetapi hati yang hancur melihat segalanya)
#
# 120. "Friendship is delicate as a glass, once broken it can be fixed but there will always be cracks." - Waqar Ahmed.
#
# (Persahabatan itu rapuh seperti kaca, sekali rusak bisa diperbaiki tapi akan selalu ada retakan)
#
# (brl/lea)

# %%
# Tokenization
text = corpus
sentence_list = nltk.sent_tokenize(text) #A list of senetences

# Print the list of sentences
print(sentence_list)
# Out:
# ['Brilio.net - Roda kehidupan selalu berputar.', 'Ada kalanya orang berada di atas, kadang juga ada di bawah.', 'Peristiwa hidup silih berganti, ada rasa bahagia, kecewa, senang, sedih, marah.', 'Semua itu pernah dirasakan setiap orang.', 'Dalam menjalani kehidupan, terkadang mengalami kesedihan yang mendalam.', 'Rasa sedih itu bisa terjadi karena berbagai faktor.', 'Bisa karena cinta, pekerjaan, keluarga, pertemanan, tetangga, ataupun dari diri sendiri.', 'Saat sedang sedih, biasanya badan akan terasa malas untuk beraktivitas dan hanya bisa melontarkan kekesalan dan kekecewaan di dalam hati.', 'Tak sedikit juga yang mau berbagi kesedihan melalui media sosial.', 'Manusia adalah makhluk Tuhan, dikaruniai perasaan dan juga akal.', 'Itulah yang menjadi salah satu alasan kata-kata sedih terasa mampu menanggapi, menggambarkan dan mewakili perasaan.', 'Meskipun begitu sebagai manusia jangan lah terlalu berlarut-larut dalam kesedihan.', 'Serahkan diri pada Yang Maha Kuasa dan kembalilah untuk bangkit.', 'Nah, berikut beberapa kata-kata sedih yang mungkin bisa mewakili perasaanmu.', 'Jadikan pengalaman sedihmu sebagai pelajaran berharga, agar kamu bisa lebih kuat lagi.', 'Simak rangkuman brilio.net dari berbagai sumber pada Selasa (29/6).', 'ANDA MUNGKIN MENYUKAI INI\n\nKata-kata sedih tentang kehidupan.', 'foto: Instagram/@motivasi_kaya\n\nHidup tidak selamanya berjalan dengan mulus.', 'Sedih dan kecewa kerap datang.', 'Setidaknya perasaanmu sedikit terwakilkan dengan membaca kata-kata sedih berikut ini.', '1.', '"Sakit sekali rasanya ketika kamu sudah melakukan yang terbaik, tapi ternyata masih tidak cukup."', '2.', '"Jangan khawatir akan hari esok kesusahan hari ini cukuplah hari ini."', '3.', '"Ketika kamu merasa sangat terluka atas sikap orang lain, maka berdoalah kepada Allah agar kamu tidak berbuat seperti apa yang telah dilakukannya."', '4.', '"Aku tidak tahu apakah tempatku benar-benar di sini.', 'Aku tidak punya seorangpun untuk diajak bicara."', '5.', '"Setiap kali orang bertanya padaku apakah aku baik-baik saja, hal ini semakin mengingatkan bahwa aku tidak baik-baik saja."', '6.', '"Orang menangis bukan karena mereka lemah.', 'Tapi, mereka menangis karena telah berusaha kuat dalam waktu yang lama."', '- Johnny Depp\n\n7.', '"Proses pendewasaan dalam hidup ini adalah melalui ujian-ujian yang terjadi dalam hidupmu."', '8.', '"Bagiku, tidur bukanlah sekadar melepas lelah, melainkan sebuah pelarian."', '9.', '"Bukan hal yang mudah melepaskan atau mempertahankan apa yang semula baik tiba-tiba berubah drastis menjadi amat buruk."', '10.', '"Salah satu perlindungan dari kekecewaan adalah memiliki kesibukan."', '- Alain de Botton.', '11.', '"Aku berharap aku dapat memberikan rasa sakitku hanya untuk sesaat sehingga kamu dapat memahami betapa kamu menyakitiku."', '- Mohsen El- guindy.', '12.', '"Beberapa hari hanyalah hari yang buruk, itu saja.', 'Kamu harus mengalami kesedihan untuk mengetahui kebahagiaan, dan saya mengingatkan diri saya sendiri bahwa tidak setiap hari akan menjadi hari yang baik, begitulah adanya!"', '- Dita Von Teese.', '13.', '"Air mata yang menetes untuk orang lain bukanlah pertanda kelemahan.', 'Itu adalah tanda hati yang murni."', '- José N. Harris.', '14.', '"Banyak hal berubah.', 'Dan teman-teman pergi.', 'Hidup tidak berhenti untuk siapa pun."', '- Stephen Chbosky.', '15.', '"Rasa sakit berkeras saat dirawat.', 'Tuhan berbisik kepada kita dalam kesenangan kita, berbicara dalam hati nurani kita, tetapi berteriak dalam kesakitan kita.', 'Itu megafon-Nya untuk membangkitkan dunia yang tuli."', '- CS Lewis.', '16.', '"Sungguh menyakitkan melihat orang yang sangat kamu cintai, mencintai orang lain.', 'Tapi, itu lebih menyakitkan ketika kamu mengetahui bahwa kamu hanyalah jembatan mereka untuk menyeberang ke orang yang mereka cintai."', '17.', '"Menyedihkan mengetahui bahwa saya sudah selesai.', 'Tapi, melihat ke belakang, saya punya banyak kenangan indah."', '- Bonnie Blair.', '18.', '"Kamu bertemu semua orang ...

# %%
def greeting_response(text):
    #Bots greeting respone
    bot_greetings = ['halo bro','hai juga','halo temanku','halo juga teman','wassup bro','hai lama gak bertemu','halo ini bot mu']
    return random.choice(bot_greetings)

# %%
 def index_sort(list_var):
    length = len(list_var)
    list_index = list(range(0, length))
    
    x = list_var        
    for i in range(length):
        for j in range(length):
            if x[list_index[i]] > x[list_index[j]]:
                #swap
                temp = list_index[i]
                list_index[i] = list_index[j]
                list_index[j] = temp
                
    return list_index

# %%
# Creat Bots Response
def bot_response(user_input):
    user_input=user_input.lower()
    sentence_list.append(user_input)
    bot_response= ''
    cm=CountVectorizer().fit_transform(sentence_list)
    similarity_scores=cosine_similarity(cm[-1],cm)
    similarity_scores_list=similarity_scores.flatten()
    index=index_sort(similarity_scores_list)
    index=index[1:]
    response_flag=0
    
    j=0
    for i in range(len(index)):
        if similarity_scores_list[index[i]]>0.0:
            bot_response=bot_response+' '+sentence_list[index[i]]
            response_flag=1
            j=j+1
        if j>2:
            break

        if response_flag==0:
            bot_response=bot_response+" "+"aku gapaham maksudmu"

        sentence_list.remove(user_input) 

        return bot_response

# %%
def speech():
    init_rec = sr.Recognizer()
    tts = gtts.gTTS("Silahkan Bicara", lang="id")
    date_string = datetime.datetime.now().strftime("%d%m%Y%H%M%S")
    filename = "voice"+date_string+".mp3"
    tts.save(filename)
    playsound(filename)
    with sr.Microphone() as source:
        audio_data = init_rec.record(source, duration=5)
        text = init_rec.recognize_google(audio_data, language="id")
        print(text)
        return text

# %%
#Start Chat
tts = gtts.gTTS("Halo, aku bot curhat silahkan curhat", lang="id")
date_string = datetime.datetime.now().strftime("%d%m%Y%H%M%S")
filename = "voice"+date_string+".mp3"
tts.save(filename)
playsound(filename)

exit_list=['exit','bye','keluar','quit', 'sampai jumpa']
user_greetings = ['halo','eh iyaa haii','hai','greetings','wassup','bot curhat']

while(True):
    user_input=str(speech())
    if user_input.lower() in exit_list:
        tts = gtts.gTTS("Perpisahan seringkali mengajarkan kita betapa berharganya seseorang setelah dia tiada, sampai jumpa lagi", lang="id")
        date_string = datetime.datetime.now().strftime("%d%m%Y%H%M%S")
        filename = "voice"+date_string+".mp3"
        tts.save(filename)
        playsound(filename)
        break
    else:
        if user_input.lower() in user_greetings:
            tts = gtts.gTTS(greeting_response(user_input), lang="id")
            date_string = datetime.datetime.now().strftime("%d%m%Y%H%M%S")
            filename = "voice"+date_string+".mp3"
            tts.save(filename)
            playsound(filename)
        else:
            tts = gtts.gTTS(bot_response(user_input), lang="id")
            date_string = datetime.datetime.now().strftime("%d%m%Y%H%M%S")
            filename = "voice"+date_string+".mp3"
            tts.save(filename)
            playsound(filename)
# Out:
# halo
# halo
# sampai jumpa
